# %%
import argparse
import scanpy as sc
import plotnine as plt9
import pandas as pd
import numpy as np
import matplotlib as plt
import os
# %load_ext autoreload
# %autoreload 2
import anndata
import seaborn as sns
import logging
import scipy.stats

# %%
fpath="/home/ubuntu/ubuntu/sc_ibd_project/ti_atlas/data/gut-freeze003/ti-cd_healthy/analysis/adata_updated/adata.h5ad"
adata=sc.read(fpath)

# %%
adata.obsm['X_umap']=adata.obsm['X_umap__n_neighbors=153,n_reduced_dims_input=29,umap_init=spectral,umap_min_dist=1pt0,umap_spread=1pt0']
sc.set_figure_params(scanpy=True, dpi=400, dpi_save=400, frameon=True, vector_friendly=True, fontsize=4, figsize=None, color_map=None, format='pdf', facecolor=None, transparent=False, ipython_format='png2x')

# %%
df1=pd.DataFrame(adata.obsm['X_umap'], columns=['UMAP1', 'UMAP2'], index=adata.obs_names)
df1.loc[:,'celltype_category']= adata.obs['celltype_category'].astype('category')
#df1.loc[:,'cell_type']= adata.obs['cell_type'].astype('category')
df1.loc[:,'celltype_label']= adata.obs['celltype_label']
#palette=plt.rcParams['axes.prop_cycle']
df1.loc[:,'CD58_log1p_cp10k']=np.array(adata[:,adata.var['gene_symbols'].isin(['CD58'])].layers['log1p_cp10k'].todense())
df1.loc[:,'CD2_log1p_cp10k']=np.array(adata[:,adata.var['gene_symbols'].isin(['CD2'])].layers['log1p_cp10k'].todense())
df1
# Out:
#                                          UMAP1      UMAP2 celltype_category  \
# CAGTGCGTCAGAGCAG-1-5892STDY8039553   11.450295  -6.446522        Stem cells
# GGGTTTAAGACGAGCT-1-5892STDY8039553   11.133955  -9.013494        Stem cells
# CATTCTACACTACCGG-1-5892STDY8039553   14.009640  -0.564600        Stem cells
# CCTCCTCCATAGGTTC-1-5892STDY8039553   10.848400  -7.051911        Stem cells
# GATGATCCACCCTTAC-1-5892STDY8039553   13.810653  -3.538153        Stem cells
# ...                                        ...        ...               ...
# CATTTCATCGTTCATT-1-OTARscRNA9342936  10.959710  12.339205            B Cell
# GAGTTACCACTAACCA-1-OTARscRNA9342936  -2.086140   0.662185            T Cell
# ACGGAAGCACTCAAGT-1-OTARscRNA9342936  -2.343098   2.256670            T Cell
# AGACTCACAAGAGATT-1-OTARscRNA9342936  -1.341134   5.566211            T Cell
# GTACAGTCAGGTACGA-1-OTARscRNA9342936  -2.669447   5.523351            T Cell
#
#                                            celltype_label  CD58_log1p_cp10k  \
# CAGTGCGTCAGAGCAG-1-5892STDY8039553   Stem cell MKI67+ (1)          0.000000
# GGGTTTAAGACGAGCT-1-5892STDY8039553   Stem cell MKI67+ (1)          0.147084
# CATTCTACACTACCGG-1-5892STDY8039553   Stem cell MKI67+ (2)          0.152658
# CCTCCTCCATAGGTTC-1-5892STDY8039553   Stem cell MKI67+ (1)          0.286648
# GATGATCCACCCTTAC-1-5892STDY8039553   Stem cell MKI67+ (2)          0.163268
# ...                                                   ...               ...
# CATTTCATCGTTCATT-1-OTARscRNA9342936                B cell          0.000000
# GAGTTACCACTAACCA-1-OTARscRNA9342936     T cell CD8+ GZMK+          0.000000
# ACGGAAGCACTCAAGT-1-OTARscRNA9342936     T cell CD8+ GZMK+          0.000000
# AGACTCACAAGAGATT-1-OTARscRNA9342936      T cell CD4 naive          0.000000
# GTACAGTCAGGTACGA-1-OTARscRNA9342936      T cell CD4- CD8-          0.000000
#
#                                      CD2_log1p_cp10k
# CAGTGCGTCAGAGCAG-1-5892STDY8039553          0.000000
# GGGTTTAAGACGAGCT-1-5892STDY8039553          0.000000
# CATTCTACACTACCGG-1-5892STDY8039553          0.000000
# CCTCCTCCATAGGTTC-1-5892STDY8039553          0.000000
# GATGATCCACCCTTAC-1-5892STDY8039553          0.000000
# ...                                              ...
# CATTTCATCGTTCATT-1-OTARscRNA9342936         0.000000
# GAGTTACCACTAACCA-1-OTARscRNA9342936         2.106596
# ACGGAAGCACTCAAGT-1-OTARscRNA9342936         3.150085
# AGACTCACAAGAGATT-1-OTARscRNA9342936         2.182429
# GTACAGTCAGGTACGA-1-OTARscRNA9342936         0.000000
#
# [141597 rows x 6 columns]

# %%
df1.to_csv("/home/ubuntu/ubuntu/sc_ibd_project/ti_atlas/manuscript/ti_atlas_code/figures/data/umap_cd58_cd2.csv", index=False)
